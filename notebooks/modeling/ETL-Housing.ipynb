# %%
import pandas as pd
import numpy as np
from path import Path

# %%
file_path = Path("../../data/zillow_data/City_Zhvi_SingleFamilyResidence.csv")

zillow_df = pd.read_csv(file_path)

zillow_df.head()
# Out:
#    Unnamed: 0  RegionID  SizeRank   RegionName RegionType StateName State  \
# 0           0      6181         0     New York       City        NY    NY
# 1           1     12447         1  Los Angeles       City        CA    CA
# 2           2     39051         2      Houston       City        TX    TX
# 3           3     17426         3      Chicago       City        IL    IL
# 4           4      6915         4  San Antonio       City        TX    TX
#
#                               Metro          CountyName  1996-01-31  ...  \
# 0       New York-Newark-Jersey City       Queens County    208545.0  ...
# 1    Los Angeles-Long Beach-Anaheim  Los Angeles County    192855.0  ...
# 2  Houston-The Woodlands-Sugar Land       Harris County     95018.0  ...
# 3          Chicago-Naperville-Elgin         Cook County    126867.0  ...
# 4         San Antonio-New Braunfels        Bexar County     94406.0  ...
#
#    2019-06-30  2019-07-31  2019-08-31  2019-09-30  2019-10-31  2019-11-30  \
# ...

# %%
state = ["FL", "CA"]

State_data = zillow_df[zillow_df.State.isin(state)]



State_data.head()
# Out:
#     Unnamed: 0  RegionID  SizeRank     RegionName RegionType StateName State  \
# 1            1     12447         1    Los Angeles       City        CA    CA
# 8            8     54296         8      San Diego       City        CA    CA
# 11          11     33839        11       San Jose       City        CA    CA
# 12          12     25290        12   Jacksonville       City        FL    FL
# 14          14     20330        14  San Francisco       City        CA    CA
#
#                              Metro            CountyName  1996-01-31  ...  \
# 1   Los Angeles-Long Beach-Anaheim    Los Angeles County    192855.0  ...
# 8               San Diego-Carlsbad      San Diego County    214715.0  ...
# 11  San Jose-Sunnyvale-Santa Clara    Santa Clara County    232040.0  ...
# 12                    Jacksonville          Duval County     85992.0  ...
# 14   San Francisco-Oakland-Hayward  San Francisco County    299060.0  ...
#
# ...

# %%
State_dropped=State_data.drop(columns=["Unnamed: 0", "RegionID", "SizeRank", "RegionType", "StateName"])

State_dropped.head()
# Out:
#        RegionName State                           Metro            CountyName  \
# 1     Los Angeles    CA  Los Angeles-Long Beach-Anaheim    Los Angeles County
# 8       San Diego    CA              San Diego-Carlsbad      San Diego County
# 11       San Jose    CA  San Jose-Sunnyvale-Santa Clara    Santa Clara County
# 12   Jacksonville    FL                    Jacksonville          Duval County
# 14  San Francisco    CA   San Francisco-Oakland-Hayward  San Francisco County
#
#     1996-01-31  1996-02-29  1996-03-31  1996-04-30  1996-05-31  1996-06-30  \
# 1     192855.0    192899.0    192974.0    193133.0    193265.0    193453.0
# 8     214715.0    214359.0    214117.0    213632.0    213343.0    213140.0
# 11    232040.0    231403.0    231196.0    230868.0    230976.0    231234.0
# 12     85992.0     86107.0     86225.0     86436.0     86621.0     86815.0
# 14    299060.0    298066.0    297387.0    296175.0    295267.0    294811.0
#
# ...

# %%
FL_CA_df = pd.melt(State_dropped, id_vars=["RegionName","State","Metro","CountyName"], 
                  var_name="Date", value_name="Avg_Price")

# %%
FL_CA_df.set_index("RegionName")
# Out:
#                    State                             Metro  \
# RegionName
# Los Angeles           CA    Los Angeles-Long Beach-Anaheim
# San Diego             CA                San Diego-Carlsbad
# San Jose              CA    San Jose-Sunnyvale-Santa Clara
# Jacksonville          FL                      Jacksonville
# San Francisco         CA     San Francisco-Oakland-Hayward
# ...                  ...                               ...
# Goodland              FL     Naples-Immokalee-Marco Island
# McIntosh              FL                             Ocala
# Camp Meeker           CA                        Santa Rosa
# Bear Valley           CA                               NaN
# North Palm Springs    CA  Riverside-San Bernardino-Ontario
#
#                               CountyName        Date  Avg_Price
# RegionName
# Los Angeles           Los Angeles County  1996-01-31   192855.0
# San Diego               San Diego County  1996-01-31   214715.0
# ...

# %%
#Export
file_path_export=Path("../../data/raw/Housing_cleaned.csv")
FL_CA_df.to_csv(file_path_export)
